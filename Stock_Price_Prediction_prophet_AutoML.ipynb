# %% [markdown]
# <a href="https://colab.research.google.com/github/umkiyoung/Time_series_analysis/blob/main/Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DataLoading

# %%
# %pip install finance-datareader
# %pip install pmdarima
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
# 삼성전자(005930), 카카오 (035720), 하이브(352820), 더네이쳐홀딩스(298540), 코엔텍(029960)
START_DATE = '2022-11-01'
END_DATE = '2023-04-21'
TICKER_LIST = ['005930', '035720', '352820', '298540', '029960']
COLUMNS_NAME = ['삼성전자', '카카오', '하이브', '더네이쳐홀딩스', '코엔텍']
PREIDCTION_DATE = [20230424,20230425,20230426,20230427,20230428]

def train_dataset_loading(ticker_list, columns_name, start_date, end_date):
    dt = pd.DataFrame()
    for i in ticker_list:
        stock = fdr.DataReader(i, start_date, end_date)
        stock_close = stock['Close']
        dt = pd.concat([dt, stock_close], axis=1)
    dt.columns = columns_name
    return dt


train_dataset = train_dataset_loading(TICKER_LIST,COLUMNS_NAME, START_DATE, END_DATE)
train_dataset.head()
# Out:
#                       삼성전자    카카오     하이브  더네이쳐홀딩스   코엔텍
# 2022-11-01 00:00:00  60000  50700  122000    27250  7990
# 2022-11-02 00:00:00  59600  52300  127000    27350  8030
# 2022-11-03 00:00:00  59200  50100  124500    27650  8040
# 2022-11-04 00:00:00  59400  50300  122500    28050  7940
# 2022-11-07 00:00:00  60200  49850  123500    27800  7900

# %% [markdown]
# ## AutoArima

# %%
from pmdarima.arima import auto_arima

def autoarima(dataframe):
    model = auto_arima(dataframe,seasonal=True, trace=True, error_action='ignore', suppress_warnings=True)
    model.fit(dataframe)
    forecast = model.predict(n_periods=5)
    return forecast


def predict_to_dtframe(train_dataset, model, seperate=True):
    
    predict = pd.DataFrame()
    if seperate: 
        for i in range(len(train_dataset.columns)):
            forecast = model(train_dataset.iloc[:,i])
            predict[train_dataset.columns[i]] = forecast
            
    else:
        forecast = model(train_dataset)
        predict = pd.DataFrame(forecast)
        predict.columns = train_dataset.columns
        
    predict['Date'] = PREIDCTION_DATE
    predict = predict[['Date',*COLUMNS_NAME]]
    predict.index = list(range(0,5))
    return predict

predict_ARIMA = predict_to_dtframe(train_dataset, autoarima)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1975.422, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1968.959, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1970.023, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1969.987, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1967.277, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1971.803, Time=0.30 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.168 seconds
# Performing stepwise search to minimize aic
# c:\Users\se99a\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2099.997, Time=0.48 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2090.876, Time=0.03 sec
# ...

# %%
predict_ARIMA
# Out:
#        Date     삼성전자      카카오            하이브  더네이쳐홀딩스          코엔텍
# 0  20230424  65700.0  57900.0  251075.630252  29150.0  7115.372602
# 1  20230425  65700.0  57900.0  252151.260504  29150.0  7109.583031
# 2  20230426  65700.0  57900.0  253226.890756  29150.0  7120.390948
# 3  20230427  65700.0  57900.0  254302.521008  29150.0  7113.845694
# 4  20230428  65700.0  57900.0  255378.151261  29150.0  7110.911119

# %% [markdown]
# ## Test_Data_Loading

# %%
def test_dataset_loading ():
    stocks = []
    for i in ['005930', '035720', '352820', '298540', '029960'] : 
        stock = fdr.DataReader(i, '2023-04-24', '2023-04-28')
        for j in range(5) :
            stocks.append(stock['Close'][j])
    submission = pd.DataFrame()
    submission['Date'] = PREIDCTION_DATE
    submission['삼성전자'] = stocks[:5]
    submission['카카오'] = stocks[5:10]
    submission['하이브'] = stocks[10:15]
    submission['더네이쳐홀딩스'] = stocks[15:20]
    submission['코엔텍'] = stocks[20:25]
    return submission
submission = test_dataset_loading()

# %%
# 오른쪽 항은 예측값을 넣으시면 됩니다!
## 아래의 오른쪽 항은 산식 산출 확인을 위해 임의로 넣은 값입니다!

def submission_prediction(submission, predict, model_name='ARIMA'):
    submission[f'삼성전자_{model_name}'] = predict['삼성전자']
    submission[f'카카오_{model_name}'] = predict['카카오']
    submission[f'하이브_{model_name}'] = predict['하이브']
    submission[f'더네이쳐홀딩스_{model_name}'] = predict['더네이쳐홀딩스']
    submission[f'코엔텍_{model_name}'] = predict['코엔텍']
    return submission

## 이 아래는 수정 사항 없습니다.

def final_score(submission, model_name='ARIMA'):
    a = np.sum(np.abs(submission['삼성전자']-submission[f'삼성전자_{model_name}']))/np.sum(submission['삼성전자'])
    b = np.sum(np.abs(submission['카카오']-submission[f'카카오_{model_name}']))/np.sum(submission['카카오'])
    c = np.sum(np.abs(submission['하이브']-submission[f'하이브_{model_name}']))/np.sum(submission['하이브'])
    d = np.sum(np.abs(submission['더네이쳐홀딩스']-submission[f'더네이쳐홀딩스_{model_name}']))/np.sum(submission['더네이쳐홀딩스'])
    e = np.sum(np.abs(submission['코엔텍']-submission[f'코엔텍_{model_name}']))/np.sum(submission['코엔텍'])
       

    final_score = np.mean([a,b,c,d,e]) * 100
    return final_score


submission = submission_prediction(submission, predict_ARIMA)
final_score(submission)
# Out:
# 2.3663644181377603

# %% [markdown]
# ## LSTM

# %%
submission
# Out:
#        Date   삼성전자    카카오     하이브  더네이쳐홀딩스   코엔텍  삼성전자_ARIMA  카카오_ARIMA  \
# 0  20230424  65200  57200  259000    28000  7170     65700.0    57900.0
# 1  20230425  63600  56000  260500    27750  7080     65700.0    57900.0
# 2  20230426  64100  56500  265000    28800  7100     65700.0    57900.0
# 3  20230427  64600  55800  264000    28000  7110     65700.0    57900.0
# 4  20230428  65500  58100  270000    28250  7070     65700.0    57900.0
#
#        하이브_ARIMA  더네이쳐홀딩스_ARIMA    코엔텍_ARIMA
# 0  251075.630252        29150.0  7115.372602
# 1  252151.260504        29150.0  7109.583031
# 2  253226.890756        29150.0  7120.390948
# 3  254302.521008        29150.0  7113.845694
# 4  255378.151261        29150.0  7110.911119

# %%
test_dataset = submission.iloc[:,:6]
test_dataset.Date = test_dataset.Date.astype('str').astype('datetime64[D]')
test_dataset = test_dataset.set_index('Date')

test_dataset
# Out:
#              삼성전자    카카오     하이브  더네이쳐홀딩스   코엔텍
# Date
# 2023-04-24  65200  57200  259000    28000  7170
# 2023-04-25  63600  56000  260500    27750  7080
# 2023-04-26  64100  56500  265000    28800  7100
# 2023-04-27  64600  55800  264000    28000  7110
# 2023-04-28  65500  58100  270000    28250  7070

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

def LSTM_train(train_dataset, test_dataset):
    # 데이터 전처리
    scaler = MinMaxScaler()  # 데이터 스케일링을 위한 scaler 객체 생성
    scaled_data_train = scaler.fit_transform(train_dataset)  # 데이터 스케일링
    scaled_data_test = scaler.transform(test_dataset)

    scaled_data = np.append(scaled_data_train, scaled_data_test, axis=0)

    # 학습 데이터와 타깃 데이터 분리
    lookback = 20  # 40개의 시점을 사용하여 다음 시점을 예측
    X = []
    y = []
    for i in range(len(scaled_data) - lookback):
        X.append(scaled_data[i:i+lookback])
        y.append(scaled_data[i+lookback])
    X = np.array(X)
    y = np.array(y)

    # 학습 데이터와 테스트 데이터 분리
    split = -5
    X_train = X[:split]
    y_train = y[:split]
    X_test = X[split:]
    y_test = y[split:]

    # LSTM 모델 구성
    model = Sequential()
    model.add(LSTM(64, input_shape=(lookback, 5)))  # 입력 형태는 (시점 수, 주식 종목 수)
    model.add(Dropout(0.2))  # Dropout 추가
    model.add(Dense(5))  # 출력은 주식 종목 수와 동일


    # 모델 컴파일 및 학습
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=200, batch_size=32)

    # 테스트 데이터로 예측 수행
    predictions = model.predict(X_test)

    # 예측 결과 복원
    predictions = scaler.inverse_transform(predictions)
    y_test = scaler.inverse_transform(y_test)

    # 예측 결과 출력
    for i in range(len(predictions)):
        print('실제값:', y_test[i])
        print('예측값:', predictions[i])
        print("MSE:", np.mean(np.square(y_test[i] - predictions[i])))
        print('---')
    
    return predictions

predictions = LSTM_train(train_dataset, test_dataset)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 3s 12ms/step - loss: 0.2310
# Epoch 2/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1234
# Epoch 3/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0623
# Epoch 4/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0602
# Epoch 5/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0551
# Epoch 6/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0406
# Epoch 7/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0338
# Epoch 8/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0337
# Epoch 9/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0296
# Epoch 10/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0280
# Epoch 11/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0246
# Epoch 12/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0258
# ...

# %%
predict_LSTM = pd.DataFrame(predictions, columns=COLUMNS_NAME, index=list(range(5)))
submission = submission_prediction(submission, predict_LSTM, model_name='LSTM')
final_score(submission, model_name='LSTM')
# Out:
# 2.6212839962740957

# %% [markdown]
# ## Prophet

# %%
from prophet import Prophet


def prophet(dataframe):
    dt = pd.DataFrame()
    forecast_dt = pd.DataFrame()
    dataframe['Date']= dataframe.index
    dataframe.index = list(range(0,len(dataframe)))
    for i in dataframe.columns:
        dt['ds'] = dataframe.Date
        dt['y'] = dataframe[i]
        model = Prophet(seasonality_mode='multiplicative', daily_seasonality=True)
        model.fit(dt)
        future = model.make_future_dataframe(periods=5)
        forecast = model.predict(future)
        forecast_dt[i] = forecast['yhat'][-5:]
    
    
    return forecast_dt
    
    

    
predict_prophet = prophet(train_dataset)
# Out:
# 14:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 14:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 14:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 14:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 14:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 14:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:35 - cmdstanpy - INFO - Chain [1] done processing

# %%
predict_prophet.index = list(range(0,5))
predict_prophet['Date'] = PREIDCTION_DATE
predict_prophet = predict_prophet[['Date',*COLUMNS_NAME]]

# %%
submission = submission_prediction(submission, predict_prophet, model_name='Prophet')
final_score(submission, model_name='Prophet')
# Out:
# 6.193197158646312

# %% [markdown]
# ## AUTOML

# %%
# %pip install autots
# Out:
# ...
#      ---------------------------------------- 1.7/1.7 MB 7.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autots import AutoTS

def autots_to_dt(train_dataset):
    dt = pd.DataFrame()
    data = pd.DataFrame()
    for i in train_dataset.columns:
        data['Date'] = train_dataset.index
        data['value'] = train_dataset[i]
        model = AutoTS(forecast_length=5, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
        model = model.fit(data, date_col='Date', value_col='value', id_col=None)
        prediction = model.predict()
        dt[i] = prediction.forecast['value']
        
    return dt

predict_autots = autots_to_dt(train_dataset)
# Out:
# Inferred frequency is: N
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# c:\Users\se99a\anaconda3\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Epoch 1/50
# 4/4 [==============================] - 8s 29ms/step - loss: 0.3701
# Epoch 2/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3698
# Epoch 3/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3688
# ...

# %%
predict_autots.index = list(range(0,5))
predict_autots['Date'] = PREIDCTION_DATE
predict_autots = predict_autots[['Date',*COLUMNS_NAME]]
predict_autots
# Out:
#        Date          삼성전자           카카오            하이브       더네이쳐홀딩스  \
# 0  20230424  65723.144132  57614.597004  250636.877105  29340.421156
# 1  20230425  65780.451075  57408.209875  252397.211001  29069.379456
# 2  20230426  65881.071699  57571.369464  252343.104081  28940.040225
# 3  20230427  65974.606543  57116.902792  251163.531991  28989.615560
# 4  20230428  66064.133607  56805.818655  254616.844140  29236.020583
#
#            코엔텍
# 0  7122.205339
# 1  7138.714929
# 2  7151.533675
# 3  7162.825525
# 4  7172.632469

# %%
submission = submission_prediction(submission, predict_autots, model_name='AutoTS')
final_score(submission, model_name='AutoTS')
# Out:
# 2.5105946429370563
